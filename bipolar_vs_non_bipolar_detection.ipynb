# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.layers import Embedding
from keras.layers import Flatten

from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences

import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix

from keras.constraints import maxnorm
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model
import time
import warnings
warnings.filterwarnings("ignore")
import pickle

# %%
# path = '/content/drive/MyDrive/final_tidy_reddits_lemmetized.json'
# df = pd.read_json(path, orient='table')
path = './final_tidy_reddits_lemmetized.csv'
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (115033, 5)

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_rows = None

# %%
df.sample(7)
# Out:
#         Unnamed: 0       label  \
# 58947        58947  depression
# 113471      113471  depression
# 22715        22715     Anxiety
# 100755      100755  depression
# 52456        52456  depression
# 99003        99003  depression
# 7976          7976     Anxiety
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 text  \
# 58947                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ['always', 'behind', 'school', 'understand', 'basic', 'math', 'instructions', 'ca', 'bothered', 'better', 'since', 'already', 'far', 'behind', 'understand', 'anything', 'school', 'tried', 'would', 'time', 'consuming', 'missed', 'much', 'always', 'bad', 'grades', 'gotten', 'worse', 'around', 'grade', 'due', 'bullying', 'would', 'miss', 'lot', 'school', 'middle', 'school', 'harassment', 'continuous', 'bullying', 'friends', 'also', 'trying', 'lose', 'weight', 'keto', 'midst', 'even', 'learned', 'drive', 'yet', 'part', 'time', 'job', 'either', 'parents', 'divorcing', 'ca', 'afford', 'move', 'dad', 'parents', 'live', 'roof', 'job', 'live', 'crummy', 'neighborhood', 'everything', 'wreck', 'unmotivated', 'relearn', 'chinese', 'croatian', 'ca', 'bothered', 'something', 'messy', 'home', 'room', 'fairly', 'clean', 'family', 'messy', 'lack', 'social', 'skills', 'handwriting', 'shit', 'sound', 'like', 'toddler', 'speak', 'know', 'even', 'go', 'college', 'grades', 'terrible', 'would', 'college', 'consider', 'feel', 'like', 'behind', 'life', 'think', 'ever', 'get', 'back', 'track']
# 113471                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['im', 'point', 'illness', 'look', 'computer', 'longer', 'im', 'research', 'assistant', 'work', 'computer', 'based', 'write', 'papers', 'input', 'data', 'things', 'like', 'ive', 'meltdowns', 'personal', 'situations', 'hit', 'constantly', 'motivation', 'write', 'desire', 'work', 'dont', 'want', 'eat', 'want', 'sleep', 'im', 'really', 'point', 'either', 'quitting', 'job', 'ending', 'work', 'meet', 'deadlines', 'stop', 'feeling', 'way', 'help', 'work']
# 22715   ['hey', 'bad', 'anxiety', 'time', 'ms', 'suicidal', 'thoughts', 'wanted', 'share', 'experience', 'dmt', 'specifically', 'affected', 'anxiety', 'bad', 'anxiety', 'light', 'schizophrenia', 'developed', 'summer', 'almost', 'dying', 'seeing', 'light', 'losing', 'mind', 'coming', 'back', 'course', 'started', 'acknowledged', 'manifested', 'tried', 'put', 'meds', 'helped', 'much', 'personally', 'med', 'shaming', 'works', 'personal', 'experience', 'felt', 'like', 'better', 'way', 'put', 'perspective', 'bad', 'anxiety', 'working', 'job', 'full', 'months', 'made', 'single', 'friend', 'person', 'go', 'enjoy', 'break', 'talk', 'outside', 'work', 'anxiety', 'makes', 'feel', 'like', 'ca', 'hold', 'new', 'friendships', 'deserve', 'makes', 'react', 'mind', 'making', 'come', 'weird', 'ca', 'look', 'felow', 'human', 'face', 'without', 'panicking', 'heart', 'feels', 'like', 'dark', 'place', 'feel', 'free', 'skip', 'spent', 'lot', 'time', 'reflecting', 'old', 'wrongs', 'selfish', 'tried', 'play', 'victim', 'things', 'spite', 'felt', 'entitled', 'let', 'ego', 'get', 'best', 'etc', 'basically', 'sourcing', 'went', 'wrong', 'things', 'stopped', 'etc', 'also', 'acknowledging', 'traumas', 'caused', 'feel', 'things', 'feel', 'think', 'way', 'became', 'cross', 'clutching', 'christian', 'although', 'left', 'religion', 'believe', 'god', 'appreciate', 'discipline', 'taught', 'thats', 'led', 'experience', 'positives', 'trip', 'experience', 'cleared', 'lot', 'stupid', 'stuff', 'often', 'think', 'worry', 'felt', 'connected', 'universe', 'earth', 'saw', 'saw', 'saw', 'everyone', 'else', 'words', 'even', 'describe', 'properly', 'everyone', 'basically', 'versions', 'made', 'realize', 'everything', 'deep', 'make', 'things', 'worry', 'trivial', 'perpetual', 'even', 'stupid', 'eyes', 'universe', 'course', 'already', 'know', 'probably', 'made', 'feel', 'get', 'saw', 'person', 'point', 'view', 'felt', 'full', 'spectrum', 'realized', 'basically', 'chilling', 'part', 'spectrum', 'could', 'maneuver', 'wanted', 'go', 'still', 'deal', 'bad', 'anxiety', 'ever', 'since', 'trip', 'times', 'remember', 'redirected', 'matter', 'far', 'stray', 'vibe', 'sensitive', 'gift', 'curse', 'realize', 'adjust', 'realize', 'trippin', 'thinking', 'want', 'beat', 'meat', 'cool', 'struggle', 'light', 'porn', 'addiction', 'increases', 'anxiety', 'ironically', 'want', 'fruits', 'vegetables', 'meat', 'feel', 'good', 'veggies', 'fruits', 'work', 'amazon', 'productive', 'next', 'day', 'work', 'still', 'social', 'opening', 'put', 'light', 'stair', 'case', 'need', 'walk', 'need', 'walking', 'im', 'slowly', 'month', 'beginning', 'able', 'look', 'people', 'face', 'downside', 'extremely', 'terrifying', 'intense', 'experience', 'told', 'friend', 'call', 'doctor', 'barely', 'able', 'say', 'powerful', 'affects', 'trying', 'say', 'call', 'ambulance', 'literally', 'could', 'say', 'universe', 'would', 'allow', 'realized', 'got', 'next', 'level', 'shit', 'resisted', 'universe', 'forced', 'submission', 'yes', 'pain', 'exists', 'yes', 'going', 'die', 'yes', 'disposable', 'small', 'something', 'huge', 'felt', 'lot', 'bad', 'shit', 'pushed', 'anxiety', 'quite', 'height', 'also', 'saw', 'bullshit', 'saw', 'faults', 'weirdly', 'made', 'get', 'supportive', 'fellow', 'friend', 'told', 'ok', 'relax', 'bit', 'panicking', 'realized', 'needed', 'submit', 'things', 'got', 'better', 'calmed', 'sometimes', 'get', 'paranoid', 'feel', 'energy', 'contagious', 'rarely', 'happens', 'already', 'paranoid', 'realize', 'things', 'deep', 'sometimes', 'give', 'bad', 'thoughts', 'little', 'immediately', 'regret', 'try', 'return', 'base', 'still', 'get', 'lost', 'though', 'things', 'still', 'feel', 'ok', 'still', 'light', 'suicidal', 'thoughts', 'always', 'get', 'eventually', 'realize', 'trippin', 'want', 'die', 'best', 'write', 'report', 'unbiased', 'unfiltered', 'simple', 'encourage', 'encourage', 'dmt', 'experience', 'someone', 'crippling', 'anxiety']
# 100755                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['since', 'subreddit', 'life', 'felt', 'okay', 'depressed', 'actually', 'happy', 'year', 'fool', 'thinking', 'would', 'last', 'tired', 'everyone', 'hates', 'tired']
# 52456                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['dont', 'want', 'talk', 'orescribe', 'pills', 'dont', 'like', 'pills', 'im', 'afraid', 'side', 'effects', 'dont', 'want', 'talk', 'parents', 'mental', 'il', 'eses']
# 99003                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['emailing', 'apologizing', 'asking', 'second', 'chance', 'getting', 'response', 'decided', 'call', 'amp', 'get', 'yes', 'effort', 'move', 'answered', 'phone', 'cheerfully', 'hi', 'wondering', 'whether', 'would', 'possible', 'speak', 'minutes', 'would', 'totally', 'understand', 'want', 'bother', 'know', 'sorry', 'name', 'pauses', 'like', 'secs', 'sternly', 'says', 'busy', 'right', 'sorry', 'hang', 'know', 'called', 'thought', 'hinting', 'reason', 'call', 'goes', 'full', 'apology', 'mode', 'wanted', 'additionally', 'state', 'deserve', 'anything', 'esp', 'happened', 'expecting', 'anything', 'wondering', 'whether', 'would', 'possible', 'given', 'second', 'chance', 'thank', 'x', 'appreciate', 'believe', 'reason', 'us', 'speak', 'ok', 'thanks', 'amp', 'nice', 'day', 'want', 'bring', 'second', 'chance', 'got', 'kind', 'response', 'apology', 'thought', 'weird', 'proceed', 'otherwise', 'esp', 'said', 'busy', 'glad', 'took', 'chance', 'call', 'conversation', 'went', 'amicably', 'despite', 'others', 'telling', 'oprah', 'said', 'get', 'courage', 'ask', 'called', 'intent', 'ask', 'second', 'chance', 'amp', 'wished', 'would', 'asked', 'adding', 'expect', 'anything', 'course', 'instead', 'waiting', 'amp', 'allowing', 'discouraged', 'said', 'busy', 'know', 'called', 'finally', 'called', 'boss', 'regarding', 'job', 'fired', 'bad', 'terms', 'apologize', 'ask', 'second', 'chance', 'call', 'went', 'wish', 'would', 'asked', 'second', 'chance', 'instead', 'feeling', 'scared']
# 7976                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['hard', 'explain', 'situations', 'almost', 'pretend', 'like', 'mean', 'still', 'personality', 'almost', 'like', 'real', 'watching', 'body', 'converse', 'almost', 'pretend', 'yet', 'get', 'like', 'say', 'talking', 'doctor', 'fake', 'confidence', 'order', 'talk', 'anyone', 'else', 'act', 'like', 'order', 'get', 'social', 'situations']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     lemmatized  \
# 58947                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['always', 'behind', 'school', 'understand', 'basic', 'math', 'instruction', 'ca', 'bother', 'well', 'since', 'already', 'far', 'behind', 'understand', 'anything', 'school', 'try', 'would', 'time', 'consume', 'miss', 'much', 'always', 'bad', 'grade', 'gotten', 'bad', 'around', 'grade', 'due', 'bullying', 'would', 'miss', 'lot', 'school', 'middle', 'school', 'harassment', 'continuous', 'bullying', 'friend', 'also', 'try', 'lose', 'weight', 'keto', 'midst', 'even', 'learn', 'drive', 'yet', 'part', 'time', 'job', 'either', 'parent', 'divorce', 'ca', 'afford', 'move', 'dad', 'parent', 'live', 'roof', 'job', 'live', 'crummy', 'neighborhood', 'everything', 'wreck', 'unmotivated', 'relearn', 'chinese', 'croatian', 'ca', 'bother', 'something', 'messy', 'home', 'room', 'fairly', 'clean', 'family', 'messy', 'lack', 'social', 'skill', 'handwrite', 'shit', 'sound', 'like', 'toddler', 'speak', 'know', 'even', 'go', 'college', 'grade', 'terrible', 'would', 'college', 'consider', 'feel', 'like', 'behind', 'life', 'think', 'ever', 'get', 'back', 'track']
# 113471                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ['im', 'point', 'illness', 'look', 'computer', 'longer', 'im', 'research', 'assistant', 'work', 'computer', 'base', 'write', 'paper', 'input', 'data', 'thing', 'like', 'ive', 'meltdown', 'personal', 'situation', 'hit', 'constantly', 'motivation', 'write', 'desire', 'work', 'dont', 'want', 'eat', 'want', 'sleep', 'im', 'really', 'point', 'either', 'quit', 'job', 'end', 'work', 'meet', 'deadline', 'stop', 'feel', 'way', 'help', 'work']
# 22715   ['hey', 'bad', 'anxiety', 'time', 'm', 'suicidal', 'thought', 'want', 'share', 'experience', 'dmt', 'specifically', 'affected', 'anxiety', 'bad', 'anxiety', 'light', 'schizophrenia', 'developed', 'summer', 'almost', 'die', 'see', 'light', 'lose', 'mind', 'come', 'back', 'course', 'start', 'acknowledge', 'manifest', 'try', 'put', 'med', 'help', 'much', 'personally', 'med', 'sham', 'work', 'personal', 'experience', 'felt', 'like', 'well', 'way', 'put', 'perspective', 'bad', 'anxiety', 'work', 'job', 'full', 'month', 'make', 'single', 'friend', 'person', 'go', 'enjoy', 'break', 'talk', 'outside', 'work', 'anxiety', 'make', 'feel', 'like', 'ca', 'hold', 'new', 'friendship', 'deserve', 'make', 'react', 'mind', 'make', 'come', 'weird', 'ca', 'look', 'felow', 'human', 'face', 'without', 'panic', 'heart', 'feel', 'like', 'dark', 'place', 'feel', 'free', 'skip', 'spent', 'lot', 'time', 'reflect', 'old', 'wrong', 'selfish', 'try', 'play', 'victim', 'thing', 'spite', 'felt', 'entitle', 'let', 'ego', 'get', 'best', 'etc', 'basically', 'source', 'go', 'wrong', 'thing', 'stop', 'etc', 'also', 'acknowledge', 'trauma', 'cause', 'feel', 'thing', 'feel', 'think', 'way', 'become', 'cross', 'clutch', 'christian', 'although', 'left', 'religion', 'believe', 'god', 'appreciate', 'discipline', 'taught', 'thats', 'lead', 'experience', 'positive', 'trip', 'experience', 'clear', 'lot', 'stupid', 'stuff', 'often', 'think', 'worry', 'felt', 'connect', 'universe', 'earth', 'saw', 'saw', 'saw', 'everyone', 'else', 'word', 'even', 'describe', 'properly', 'everyone', 'basically', 'version', 'make', 'realize', 'everything', 'deep', 'make', 'thing', 'worry', 'trivial', 'perpetual', 'even', 'stupid', 'eye', 'universe', 'course', 'already', 'know', 'probably', 'make', 'feel', 'get', 'saw', 'person', 'point', 'view', 'felt', 'full', 'spectrum', 'realize', 'basically', 'chill', 'part', 'spectrum', 'could', 'maneuver', 'want', 'go', 'still', 'deal', 'bad', 'anxiety', 'ever', 'since', 'trip', 'time', 'remember', 'redirect', 'matter', 'far', 'stray', 'vibe', 'sensitive', 'gift', 'curse', 'realize', 'adjust', 'realize', 'trippin', 'think', 'want', 'beat', 'meat', 'cool', 'struggle', 'light', 'porn', 'addiction', 'increase', 'anxiety', 'ironically', 'want', 'fruit', 'vegetable', 'meat', 'feel', 'good', 'veggie', 'fruit', 'work', 'amazon', 'productive', 'next', 'day', 'work', 'still', 'social', 'opening', 'put', 'light', 'stair', 'case', 'need', 'walk', 'need', 'walk', 'im', 'slowly', 'month', 'begin', 'able', 'look', 'people', 'face', 'downside', 'extremely', 'terrify', 'intense', 'experience', 'told', 'friend', 'call', 'doctor', 'barely', 'able', 'say', 'powerful', 'affect', 'try', 'say', 'call', 'ambulance', 'literally', 'could', 'say', 'universe', 'would', 'allow', 'realize', 'get', 'next', 'level', 'shit', 'resist', 'universe', 'force', 'submission', 'yes', 'pain', 'exists', 'yes', 'go', 'die', 'yes', 'disposable', 'small', 'something', 'huge', 'felt', 'lot', 'bad', 'shit', 'push', 'anxiety', 'quite', 'height', 'also', 'saw', 'bullshit', 'saw', 'fault', 'weirdly', 'make', 'get', 'supportive', 'fellow', 'friend', 'told', 'ok', 'relax', 'bit', 'panic', 'realize', 'need', 'submit', 'thing', 'get', 'well', 'calm', 'sometimes', 'get', 'paranoid', 'feel', 'energy', 'contagious', 'rarely', 'happens', 'already', 'paranoid', 'realize', 'thing', 'deep', 'sometimes', 'give', 'bad', 'thought', 'little', 'immediately', 'regret', 'try', 'return', 'base', 'still', 'get', 'lose', 'though', 'thing', 'still', 'feel', 'ok', 'still', 'light', 'suicidal', 'thought', 'always', 'get', 'eventually', 'realize', 'trippin', 'want', 'die', 'best', 'write', 'report', 'unbiased', 'unfiltered', 'simple', 'encourage', 'encourage', 'dmt', 'experience', 'someone', 'cripple', 'anxiety']
# ...
# 113471                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          im point illness look computer longer im research assistant work computer base write paper input data thing like ive meltdown personal situation hit constantly motivation write desire work dont want eat want sleep im really point either quit job end work meet deadline stop feel way help work
# 22715   hey bad anxiety time m suicidal thought want share experience dmt specifically affected anxiety bad anxiety light schizophrenia developed summer almost die see light lose mind come back course start acknowledge manifest try put med help much personally med sham work personal experience felt like well way put perspective bad anxiety work job full month make single friend person go enjoy break talk outside work anxiety make feel like ca hold new friendship deserve make react mind make come weird ca look felow human face without panic heart feel like dark place feel free skip spent lot time reflect old wrong selfish try play victim thing spite felt entitle let ego get best etc basically source go wrong thing stop etc also acknowledge trauma cause feel thing feel think way become cross clutch christian although left religion believe god appreciate discipline taught thats lead experience positive trip experience clear lot stupid stuff often think worry felt connect universe earth saw saw saw everyone else word even describe properly everyone basically version make realize everything deep make thing worry trivial perpetual even stupid eye universe course already know probably make feel get saw person point view felt full spectrum realize basically chill part spectrum could maneuver want go still deal bad anxiety ever since trip time remember redirect matter far stray vibe sensitive gift curse realize adjust realize trippin think want beat meat cool struggle light porn addiction increase anxiety ironically want fruit vegetable meat feel good veggie fruit work amazon productive next day work still social opening put light stair case need walk need walk im slowly month begin able look people face downside extremely terrify intense experience told friend call doctor barely able say powerful affect try say call ambulance literally could say universe would allow realize get next level shit resist universe force submission yes pain exists yes go die yes disposable small something huge felt lot bad shit push anxiety quite height also saw bullshit saw fault weirdly make get supportive fellow friend told ok relax bit panic realize need submit thing get well calm sometimes get paranoid feel energy contagious rarely happens already paranoid realize thing deep sometimes give bad thought little immediately regret try return base still get lose though thing still feel ok still light suicidal thought always get eventually realize trippin want die best write report unbiased unfiltered simple encourage encourage dmt experience someone cripple anxiety
# 100755                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    since subreddit life felt okay depressed actually happy year fool think would last tire everyone hate tire
# 52456                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          dont want talk orescribe pill dont like pill im afraid side effect dont want talk parent mental il es
# 99003                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        email apologize ask second chance get response decide call amp get yes effort move answer phone cheerfully hi wonder whether would possible speak minute would totally understand want bother know sorry name pause like sec sternly say busy right sorry hang know call thought hint reason call go full apology mode want additionally state deserve anything esp happen expect anything wonder whether would possible give second chance thank x appreciate believe reason u speak ok thanks amp nice day want bring second chance get kind response apology thought weird proceed otherwise esp say busy glad take chance call conversation go amicably despite others tell oprah say get courage ask call intent ask second chance amp wish would ask add expect anything course instead wait amp allow discourage say busy know call finally call bos regard job fire bad term apologize ask second chance call go wish would ask second chance instead feel scar
# 7976                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   hard explain situation almost pretend like mean still personality almost like real watch body converse almost pretend yet get like say talk doctor fake confidence order talk anyone else act like order get social situation

# %%
df.isna().sum()
# Out:
# Unnamed: 0             0
# label                  0
# text                   0
# lemmatized             0
# tokens_back_to_text    6
# dtype: int64

# %%
reddits = list(df['tokens_back_to_text'])
type(reddits)
# Out:
# list

# %%
len(reddits)
# Out:
# 115033

# %%
df['label'].value_counts()
# Out:
# depression    69217
# Anxiety       36257
# bipolar        9559
# Name: label, dtype: int64

# %%
df['label'] = np.where(df['label']=='bipolar',1,0)

# %%
df.head(3)
# Out:
#    Unnamed: 0  label  \
# 0           0      0
# 1           1      0
# 2           2      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['smirk', 'face', 'like', 'im', 'high', 'feel', 'pretty', 'good', 'longer', 'feel', 'anxious', 'im', 'peering', 'behind', 'back', 'every', 'second', 'didnt', 'expect', 'feel', 'good', 'anyone', 'ideas', 'propranolol', 'making', 'feel', 'somewhat', 'high']
# 1  ['minutes', 'ago', 'posted', 'something', 'another', 'subreddit', 'convince', 'minutes', 'good', 'post', 'finally', 'posted', 'suddenly', 'got', 'anxious', 'like', 'anxious', 'could', 'hear', 'heart', 'beating', 'started', 'breath', 'faster', 'etc', 'end', 'deleted', 'post', 'happened', 'many', 'times', 'often', 'writing', 'something', 'group', 'chats', 'strangers', 'discord', 'generally', 'posting', 'comment', 'social', 'media', 'commenting', 'friends', 'post', 'sth', 'like', 'even', 'chatting', 'people', 'online', 'makes', 'uncomfortable', 'think', 'might', 'react', 'way', 'might', 'afraid', 'rejection', 'feeling', 'left', 'someone', 'responding', 'liking', 'confuses', 'feel', 'way', 'irl', 'good', 'friends', 'never', 'dealt', 'rejection', 'since', 'sociable', 'also', 'dont', 'really', 'care', 'people', 'think', 'reason', 'really', 'seems', 'bother', 'particular', 'situations', 'anyone', 'advice', 'overcome', 'fear', 'btw', 'dont', 'feel', 'way', 'asking', 'help', 'like', 'right', 'diagnosed', 'anxiety', 'disorder', 'think', 'one', 'either', 'looking', 'advice', 'subreddit', 'anxious', 'posting', 'reddit', 'group', 'chats']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['feel', 'anxious', 'college', 'body', 'started', 'showing', 'signs', 'heat', 'chest', 'think', 'lot', 'makes', 'anxious', 'afraid', 'go', 'college', 'especially', 'pandemic', 'need', 'group', 'fit', 'feel', 'anxious', 'college']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                lemmatized  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['smirk', 'face', 'like', 'im', 'high', 'feel', 'pretty', 'good', 'longer', 'feel', 'anxious', 'im', 'peer', 'behind', 'back', 'every', 'second', 'didnt', 'expect', 'feel', 'good', 'anyone', 'idea', 'propranolol', 'make', 'feel', 'somewhat', 'high']
# 1  ['minute', 'ago', 'post', 'something', 'another', 'subreddit', 'convince', 'minute', 'good', 'post', 'finally', 'post', 'suddenly', 'get', 'anxious', 'like', 'anxious', 'could', 'hear', 'heart', 'beating', 'start', 'breath', 'faster', 'etc', 'end', 'delete', 'post', 'happen', 'many', 'time', 'often', 'write', 'something', 'group', 'chat', 'stranger', 'discord', 'generally', 'post', 'comment', 'social', 'medium', 'comment', 'friend', 'post', 'sth', 'like', 'even', 'chat', 'people', 'online', 'make', 'uncomfortable', 'think', 'might', 'react', 'way', 'might', 'afraid', 'rejection', 'feel', 'left', 'someone', 'respond', 'like', 'confuses', 'feel', 'way', 'irl', 'good', 'friend', 'never', 'dealt', 'rejection', 'since', 'sociable', 'also', 'dont', 'really', 'care', 'people', 'think', 'reason', 'really', 'seem', 'bother', 'particular', 'situation', 'anyone', 'advice', 'overcome', 'fear', 'btw', 'dont', 'feel', 'way', 'ask', 'help', 'like', 'right', 'diagnose', 'anxiety', 'disorder', 'think', 'one', 'either', 'look', 'advice', 'subreddit', 'anxious', 'post', 'reddit', 'group', 'chat']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['feel', 'anxious', 'college', 'body', 'start', 'show', 'sign', 'heat', 'chest', 'think', 'lot', 'make', 'anxious', 'afraid', 'go', 'college', 'especially', 'pandemic', 'need', 'group', 'fit', 'feel', 'anxious', 'college']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             tokens_back_to_text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          smirk face like im high feel pretty good longer feel anxious im peer behind back every second didnt expect feel good anyone idea propranolol make feel somewhat high
# 1  minute ago post something another subreddit convince minute good post finally post suddenly get anxious like anxious could hear heart beating start breath faster etc end delete post happen many time often write something group chat stranger discord generally post comment social medium comment friend post sth like even chat people online make uncomfortable think might react way might afraid rejection feel left someone respond like confuses feel way irl good friend never dealt rejection since sociable also dont really care people think reason really seem bother particular situation anyone advice overcome fear btw dont feel way ask help like right diagnose anxiety disorder think one either look advice subreddit anxious post reddit group chat
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         feel anxious college body start show sign heat chest think lot make anxious afraid go college especially pandemic need group fit feel anxious college

# %%
df['label'].value_counts()
# Out:
# 0    105474
# 1      9559
# Name: label, dtype: int64

# %% [markdown]
# ## **Feature extraction**

# %%
# prepare tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts([str(x) for x in reddits])

# %%
word_index = tokenizer.word_index
print('WE HAVE %s UNIQUE TOKENS.' % len(word_index))
# Out:
# WE HAVE 57670 UNIQUE TOKENS.

# %%
sequences = tokenizer.texts_to_sequences([str(x) for x in reddits])

# %%
with open('bipolar.sequences.pkl', 'wb') as f:
    pickle.dump(sequences, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# pad redddits to a max length of 150 words
maxlen = 150
X = pad_sequences(sequences, maxlen = maxlen)
X.shape
# Out:
# (115033, 150)

# %%
y = df['label']

# %% [markdown]
# ##Split the dataset into **training** and **test** sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((92026, 150), (23007, 150), (92026,), (23007,))

# %%
y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
y_test = np.asarray(y_test).astype('float32').reshape((-1,1))

# %% [markdown]
# # Defining the **Convolutional Neural Network Model**

# %%
# Prepare hyperparameters of CNN
vocab_size = len(word_index) + 1
# output_dim = 32

# %%
# Building the CNN Model
model = Sequential()

model.add(Embedding(vocab_size, 128, input_length=maxlen))
model.add(Conv1D(128, 3, padding='same', activation='relu'))
model.add(Conv1D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling1D())
model.add(Flatten())

model.add(Dense(250, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Visualizing the CNN Model

# %%
plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 128)          7381888
#
#  conv1d (Conv1D)             (None, 150, 128)          49280
#
#  conv1d_1 (Conv1D)           (None, 150, 64)           24640
#
#  max_pooling1d (MaxPooling1D  (None, 75, 64)           0
#  )
#
#  flatten (Flatten)           (None, 4800)              0
#
#  dense (Dense)               (None, 250)               1200250
#
#  dense_1 (Dense)             (None, 1)                 251
#
# =================================================================
# Total params: 8,656,309
# Trainable params: 8,656,309
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Using the **Adam optimizer** for the optimization and **Binary cross entropy** to calculate the Loss Function

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
start = time.time()

# fit the model to the training set
cnn_hist = model.fit(X_train, y_train, epochs = 5, validation_split = 0.2)

# evaluation of the model on the test set
scores = model.evaluate(X_test, y_test, verbose = 0)
print("Accuracy: %.2f%%" % (scores[1]*100))
warnings.filterwarnings("ignore")

end = time.time()
total = (end-start) // 60
print('Training duration : {} minutes'.format(total))
# Out:
# Epoch 1/5
# 2301/2301 [==============================] - 579s 251ms/step - loss: 0.1403 - accuracy: 0.9575 - val_loss: 0.1221 - val_accuracy: 0.9641
# Epoch 2/5
# 2301/2301 [==============================] - 964s 419ms/step - loss: 0.0938 - accuracy: 0.9706 - val_loss: 0.1250 - val_accuracy: 0.9646
# Epoch 3/5
# 2301/2301 [==============================] - 940s 409ms/step - loss: 0.0592 - accuracy: 0.9806 - val_loss: 0.1599 - val_accuracy: 0.9552
# Epoch 4/5
# 2301/2301 [==============================] - 999s 434ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 0.2025 - val_accuracy: 0.9530
# Epoch 5/5
# 2301/2301 [==============================] - 1056s 459ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.3245 - val_accuracy: 0.9549
# Accuracy: 95.51%
# Training duration : 77.0 minutes

# %%
history_dict = cnn_hist.history

# %% [markdown]
# ## **Plotting the loss and the accuracy of both training and validation sets using the model history**

# %%
# loss
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1) 

# plot
plt.figure(figsize=(12, 8))
plt.plot(epochs, loss_values, 'green',label='Training loss')
plt.plot(epochs, val_loss_values, 'red', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# accuracy
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

# range of X (no. of epochs)
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12, 8))
plt.plot(epochs, acc, 'green',label='Training accuracy')
# orange is for "orange"
plt.plot(epochs, val_acc, 'red', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## **Confusion matrix**

# %%
preds = np.round(model.predict(X_test), 0)
# Out:
# 719/719 [==============================] - 59s 80ms/step

# %%
cm = confusion_matrix(y_test, preds)

# %%
df_cm = pd.DataFrame(cm, index = ["depression", "non-depression"], columns = ["depression", "non-depression"])

# %%
plt.figure(figsize=(6, 4))
sb.set_theme()
sb.heatmap(df_cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('True Class')
plt.ylabel('Predicted Class')
# Out:
# Text(30.499999999999993, 0.5, 'Predicted Class')

# %%
with open('bipolar.model.pkl', 'wb') as f:
    pickle.dump(model, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://48efd1d0-40de-41e9-a94d-8b441d81e54d/assets
# INFO:tensorflow:Assets written to: ram://48efd1d0-40de-41e9-a94d-8b441d81e54d/assets
